# %%
task=int(input())
for i in range(task):
    tc=int(input())
    list1=[]
    matrix=[[0]*(4) for i in range(4)]
    for j in range(tc):
        ls=[]
        ls=list(map(int,input().split()))
        if(ls[0]=='A'):
            if(ls[1]=='12'):
                matrix[0][0]=matrix[0][0]+1
            if(ls[1]=='3'):
                matrix[0][1]=matrix[0][1]+1
            if(ls[1]=='6'):
                matrix[0][2]=matrix[0][2]+1
            if(ls[1]=='9'):
                matrix[0][3]=matrix[0][3]+1
            
        if(ls[0]=='B'):
            if(ls[1]=='12'):
                matrix[1][0]=matrix[1][0]+1
            if(ls[1]=='3'):
                matrix[1][1]=matrix[1][1]+1
            if(ls[1]=='6'):
                matrix[1][2]=matrix[1][2]+1
            if(ls[1]=='9'):
                matrix[1][3]=matrix[1][3]+1

        if(ls[0]=='C'):
            if(ls[1]=='12'):
                matrix[2][0]=matrix[2][0]+1
            if(ls[1]=='3'):
                matrix[2][1]=matrix[2][1]+1
            if(ls[1]=='6'):
                matrix[2][2]=matrix[2][2]+1
            if(ls[1]=='9'):
                matrix[2][3]=matrix[2][3]+1
        if(ls[0]=='D'):
            if(ls[1]=='12'):
                matrix[3][0]=matrix[3][0]+1
            if(ls[1]=='3'):
                matrix[3][1]=matrix[3][1]+1
            if(ls[1]=='6'):
                matrix[3][2]=matrix[3][2]+1
            if(ls[1]=='9'):
                matrix[3][3]=matrix[3][3]+1

    max12=0
    max6=0
    max9=0
    max3=0
    max12=max(matrix[0][0],matrix[1][0],matrix[2][0],matrix[3][0])
    max3=max(matrix[0][1],matrix[1][1],matrix[2][1],matrix[3][1])
    max6=max(matrix[0][2],matrix[1][2],matrix[2][2],matrix[3][2])
    max9=max(matrix[0][3],matrix[1][3],matrix[2][3],matrix[3][3])
    
    ma1=max(max12,max3,max6,max9)
    for
